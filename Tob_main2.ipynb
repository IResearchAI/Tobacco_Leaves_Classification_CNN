# %% [markdown]
# # MobileNet Implementation

# %%
# %%capture
# !pip install pydot
# !apt-get install graphviz
# !sed -i 's/def _check_pydot()/def _check__pydot()/g' /usr/local/lib/python3.6/dist-packages/keras/utils/vis_utils.py
# !sed -i 's/_check_pydot()/#_check_pydot()/g' /usr/local/lib/python3.6/dist-packages/keras/utils/vis_utils.py

# %%
import numpy as np
import pandas as pd 
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
import os
print(os.listdir("../tob2/data/train"))
# Out:
# Using TensorFlow backend.
# /home/shiv/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/shiv/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/shiv/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/shiv/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/shiv/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/shiv/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/shiv/.local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/shiv/.local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/shiv/.local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/shiv/.local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/shiv/.local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/shiv/.local/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# ['c2.399.jpg', 'c3.642.jpg', 'c1.718.jpg', 'c1.274.jpg', 'c3.756.jpg', 'c1.564.jpg', 'c2.386.jpg', 'c2.327.jpg', 'c3.798.jpg', 'c4.696.jpg', 'c2.321.jpg', 'c2.707.jpg', 'c4.147.jpg', 'c1.496.jpg', 'c1.799.jpg', 'c2.505.jpg', 'c1.477.jpg', 'c2.674.jpg', 'c3.134.jpg', 'c2.529.jpg', 'c2.423.jpg', 'c2.518.jpg', 'c2.591.jpg', 'c1.60.jpg', 'c1.15.jpg', 'c2.755.jpg', 'c2.205.jpg', 'c4.509.jpg', 'c3.86.jpg', 'c3.486.jpg', 'c3.44.jpg', 'c3.113.jpg', 'c3.130.jpg', 'c3.304.jpg', 'c4.113.jpg', 'c2.173.jpg', 'c3.61.jpg', 'c1.150.jpg', 'c1.586.jpg', 'c4.699.jpg', 'c1.478.jpg', 'c3.112.jpg', 'c4.2.jpg', 'c3.173.jpg', 'c2.133.jpg', 'c1.697.jpg', 'c2.495.jpg', 'c4.709.jpg', 'c4.338.jpg', 'c1.661.jpg', 'c4.254.jpg', 'c1.87.jpg', 'c4.546.jpg', 'c1.224.jpg', 'c1.254.jpg', 'c1.172.jpg', 'c2.138.jpg', 'c4.585.jpg', 'c4.563.jpg', 'c1.549.jpg', 'c4.750.jpg', 'c4.603.jpg', 'c4.224.jpg', 'c2.416.jpg', 'c4.727.jpg', 'c4.201.jpg', 'c1.738.jpg', 'c3.382.jpg', 'c3.295.jpg', 'c2.652.jpg', 'c2.510.jpg', 'c2.340.jpg', 'c1.449.jpg', 'c1.190.jpg', 'c2.270.jpg', 'c3.201.jpg', 'c3.384.jpg', 'c3.377.jpg', 'c4.155.jpg', 'c3.693.jpg', 'c4.210.jpg', 'c4.513.jpg', 'c1.519.jpg', 'c4.682.jpg', 'c3.225.jpg', 'c1.131.jpg', 'c4.763.jpg', 'c2.43.jpg', 'c3.543.jpg', 'c1.380.jpg', 'c2.611.jpg', 'c2.681.jpg', 'c2.49.jpg', 'c2.308.jpg', 'c1.236.jpg', 'c3.101.jpg', 'c4.406.jpg', 'c3.647.jpg', 'c4.272.jpg', 'c1.641.jpg', 'c2.543.jpg', 'c3.0.jpg', 'c4.473.jpg', 'c1.783.jpg', 'c3.396.jpg', 'c1.769.jpg', 'c2.491.jpg', 'c4.618.jpg', 'c4.34.jpg', 'c4.584.jpg', 'c2.514.jpg', 'c3.362.jpg', 'c3.566.jpg', 'c4.343.jpg', 'c1.584.jpg', 'c1.555.jpg', 'c4.285.jpg', 'c4.462.jpg', 'c4.431.jpg', 'c1.281.jpg', 'c1.89.jpg', 'c1.724.jpg', 'c3.386.jpg', 'c2.660.jpg', 'c3.467.jpg', 'c3.414.jpg', 'c3.345.jpg', 'c1.457.jpg', 'c4.327.jpg', 'c4.79.jpg', 'c1.306.jpg', 'c3.516.jpg', 'c3.271.jpg', 'c1.251.jpg', 'c4.56.jpg', 'c2.264.jpg', 'c4.617.jpg', 'c1.344.jpg', 'c1.280.jpg', 'c4.36.jpg', 'c4.161.jpg', 'c4.163.jpg', 'c1.459.jpg', 'c4.562.jpg', 'c1.147.jpg', 'c1.607.jpg', 'c2.330.jpg', 'c1.642.jpg', 'c2.596.jpg', 'c3.600.jpg', 'c1.409.jpg', 'c4.90.jpg', 'c2.396.jpg', 'c4.238.jpg', 'c4.769.jpg', 'c3.265.jpg', 'c3.438.jpg', 'c3.608.jpg', 'c3.588.jpg', 'c4.541.jpg', 'c4.299.jpg', 'c2.607.jpg', 'c1.339.jpg', 'c1.240.jpg', 'c2.612.jpg', 'c2.633.jpg', 'c2.176.jpg', 'c2.107.jpg', 'c1.545.jpg', 'c3.226.jpg', 'c1.773.jpg', 'c3.580.jpg', 'c1.129.jpg', 'c2.335.jpg', 'c3.62.jpg', 'c4.242.jpg', 'c1.740.jpg', 'c2.81.jpg', 'c4.519.jpg', 'c2.319.jpg', 'c2.765.jpg', 'c2.12.jpg', 'c3.328.jpg', 'c1.782.jpg', 'c1.777.jpg', 'c1.13.jpg', 'c3.177.jpg', 'c3.199.jpg', 'c3.351.jpg', 'c3.8.jpg', 'c1.219.jpg', 'c2.498.jpg', 'c4.227.jpg', 'c3.191.jpg', 'c4.690.jpg', 'c2.746.jpg', 'c3.309.jpg', 'c3.682.jpg', 'c3.695.jpg', 'c1.206.jpg', 'c1.125.jpg', 'c3.59.jpg', 'c2.163.jpg', 'c4.170.jpg', 'c1.759.jpg', 'c3.33.jpg', 'c2.367.jpg', 'c4.570.jpg', 'c3.374.jpg', 'c2.581.jpg', 'c3.678.jpg', 'c1.554.jpg', 'c4.762.jpg', 'c1.194.jpg', 'c2.266.jpg', 'c4.208.jpg', 'c3.14.jpg', 'c1.45.jpg', 'c2.87.jpg', 'c1.720.jpg', 'c3.156.jpg', 'c4.427.jpg', 'c3.728.jpg', 'c1.9.jpg', 'c4.493.jpg', 'c1.559.jpg', 'c2.122.jpg', 'c1.16.jpg', 'c1.779.jpg', 'c2.710.jpg', 'c4.67.jpg', 'c4.753.jpg', 'c3.117.jpg', 'c3.70.jpg', 'c3.675.jpg', 'c4.142.jpg', 'c2.198.jpg', 'c4.674.jpg', 'c2.702.jpg', 'c3.774.jpg', 'c3.562.jpg', 'c4.407.jpg', 'c4.799.jpg', 'c4.716.jpg', 'c3.491.jpg', 'c2.366.jpg', 'c1.699.jpg', 'c1.491.jpg', 'c3.692.jpg', 'c1.785.jpg', 'c4.658.jpg', 'c1.790.jpg', 'c1.250.jpg', 'c4.219.jpg', 'c1.114.jpg', 'c2.203.jpg', 'c3.339.jpg', 'c3.400.jpg', 'c2.525.jpg', 'c1.239.jpg', 'c4.31.jpg', 'c4.305.jpg', 'c1.659.jpg', 'c2.787.jpg', 'c3.681.jpg', 'c4.24.jpg', 'c3.301.jpg', 'c4.337.jpg', 'c1.742.jpg', 'c2.333.jpg', 'c2.420.jpg', 'c4.400.jpg', 'c1.169.jpg', 'c2.631.jpg', 'c4.25.jpg', 'c3.266.jpg', 'c2.667.jpg', 'c1.216.jpg', 'c4.174.jpg', 'c4.351.jpg', 'c2.745.jpg', 'c2.704.jpg', 'c3.103.jpg', 'c1.758.jpg', 'c1.617.jpg', 'c1.142.jpg', 'c2.615.jpg', 'c4.796.jpg', 'c1. ...

# %%
import keras
import keras.backend as K
from keras.models import Model
from keras.layers import Input, Dense, Conv2D, Conv3D, DepthwiseConv2D, SeparableConv2D, Conv3DTranspose
from keras.layers import Flatten, MaxPool2D, AvgPool2D, GlobalAvgPool2D, UpSampling2D, BatchNormalization
from keras.layers import Concatenate, Add, Dropout, ReLU, Lambda, Activation, LeakyReLU, PReLU

from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

from time import time
import numpy as np

# %%
FAST_RUN = False
IMAGE_WIDTH=150
IMAGE_HEIGHT=150
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3

# %%
filenames = os.listdir("../tob2/data/train")
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    if category == 'c1':
        categories.append(0)
    elif category == 'c2':
        categories.append(1)
    elif category == 'c3':
        categories.append(2)
    else:
        categories.append(3)

df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
df['category'].value_counts()
# Out:
# 3    800
# 1    800
# 2    800
# 0    800
# Name: category, dtype: int64

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
earlystop = EarlyStopping(patience=10)

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
callbacks = [earlystop, learning_rate_reduction]

# %%
df["category"] = df["category"].replace({0: 'c1', 1: 'c2', 2:'c3', 3:'c4'})

# %%
total_train =df.shape[0]

batch_size=15

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

train_generator = train_datagen.flow_from_dataframe(
    df, 
    "../tob2/data/train", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 3200 validated image filenames belonging to 4 classes.

# %%
df = df.reset_index(drop=True)
df
# Out:
#         filename category
# 0     c2.399.jpg       c2
# 1     c3.642.jpg       c3
# 2     c1.718.jpg       c1
# 3     c1.274.jpg       c1
# 4     c3.756.jpg       c3
# ...          ...      ...
# 3195  c1.578.jpg       c1
# 3196  c4.511.jpg       c4
# 3197  c2.231.jpg       c2
# 3198  c1.500.jpg       c1
# 3199  c4.440.jpg       c4
#
# [3200 rows x 2 columns]

# %%
filenames = os.listdir("../tob2/data/validation")
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    if category == 'c1':
        categories.append(0)
    elif category == 'c2':
        categories.append(1)
    elif category == 'c3':
        categories.append(2)
    else:
        categories.append(3)

df1 = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
df1["category"] = df1["category"].replace({0: 'c1', 1: 'c2', 2:'c3', 3:'c4'})

# %%
df1 = df1.reset_index(drop=True)
df1
# Out:
#        filename category
# 0    c4.147.jpg       c4
# 1    c3.134.jpg       c3
# 2     c1.60.jpg       c1
# 3     c1.15.jpg       c1
# 4     c3.86.jpg       c3
# ..          ...      ...
# 795  c1.197.jpg       c1
# 796  c4.169.jpg       c4
# 797  c3.154.jpg       c3
# 798   c3.84.jpg       c3
# 799  c3.182.jpg       c3
#
# [800 rows x 2 columns]

# %%
total_validate =df1.shape[0]

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    df1, 
    "../tob2/data/validation", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 800 validated image filenames belonging to 4 classes.

# %%
def mobilenet(input_shape, n_classes):
  
  def mobilenet_block(x, f, s=1):
    x = DepthwiseConv2D(3, strides=s, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    
    x = Conv2D(f, 1, strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    return x
    
    
  input = Input(input_shape)

  x = Conv2D(32, 3, strides=2, padding='same')(input)
  x = BatchNormalization()(x)
  x = ReLU()(x)

  x = mobilenet_block(x, 64)
  x = mobilenet_block(x, 128, 2)
  x = mobilenet_block(x, 128)

  x = mobilenet_block(x, 256, 2)
  x = mobilenet_block(x, 256)

  x = mobilenet_block(x, 512, 2)
  for _ in range(5):
    x = mobilenet_block(x, 512)

  x = mobilenet_block(x, 1024, 2)
  x = mobilenet_block(x, 1024)
  
  x = GlobalAvgPool2D()(x)
  
  output = Dense(n_classes, activation='softmax')(x)
  
  model = Model(input, output)
  return model

# %%
input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS);
n_classes = 4;
model = mobilenet(input_shape,n_classes);
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 150, 150, 3)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 32)        896
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 75, 75, 32)        128
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 75, 75, 32)        0
# _________________________________________________________________
# depthwise_conv2d_1 (Depthwis (None, 75, 75, 32)        320
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 75, 75, 32)        128
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 75, 75, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 75, 75, 64)        2112
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 75, 75, 64)        256
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 75, 75, 64)        0
# _________________________________________________________________
# depthwise_conv2d_2 (Depthwis (None, 38, 38, 64)        640
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 38, 38, 64)        256
# _________________________________________________________________
# re_lu_4 (ReLU)               (None, 38, 38, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 38, 38, 128)       8320
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 38, 38, 128)       512
# _________________________________________________________________
# re_lu_5 (ReLU)               (None, 38, 38, 128)       0
# _________________________________________________________________
# depthwise_conv2d_3 (Depthwis (None, 38, 38, 128)       1280
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 38, 38, 128)       512
# _________________________________________________________________
# re_lu_6 (ReLU)               (None, 38, 38, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 38, 38, 128)       16512
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 38, 38, 128)       512
# _________________________________________________________________
# re_lu_7 (ReLU)               (None, 38, 38, 128)       0
# _________________________________________________________________
# depthwise_conv2d_4 (Depthwis (None, 19, 19, 128)       1280
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 19, 19, 128)       512
# _________________________________________________________________
# re_lu_8 (ReLU)               (None, 19, 19, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 19, 19, 256)       33024
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 19, 19, 256)       1024
# _________________________________________________________________
# re_lu_9 (ReLU)               (None, 19, 19, 256)       0
# _________________________________________________________________
# depthwise_conv2d_5 (Depthwis (None, 19, 19, 256)       2560
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 19, 19, 256)       1024
# _________________________________________________________________
# re_lu_10 (ReLU)              (None, 19, 19, 256)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 19, 19, 256)       65792
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 19, 19, 256)       1024
# _________________________________________________________________
# re_lu_11 (ReLU)              (None, 19, 19, 256)       0
# _________________________________________________________________
# depthwise_conv2d_6 (Depthwis (None, 10, 10, 256)       2560
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 10, 10, 256)       1024
# _________________________________________________________________
# re_lu_12 (ReLU)              (None, 10, 10, 256)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 10, 10, 512)       131584
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 10, 10, 512)       2048
# _________________________________________________________________
# re_lu_13 (ReLU)              (None, 10, 10, 512)       0
# _________________________________________________________________
# depthwise_conv2d_7 (Depthwis (None, 10, 10, 512)       5120
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 10, 10, 512)       2048
# _________________________________________________________________
# re_lu_14 (ReLU)              (None, 10, 10, 512)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 10, 10, 512)       262656
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 10, 10, 512)       2048
# _________________________________________________________________
# re_lu_15 (ReLU)              (None, 10, 10, 512)       0
# _________________________________________________________________
# depthwise_conv2d_8 (Depthwis (None, 10, 10, 512)       5120
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 10, 10, 512)       2048
# _________________________________________________________________
# re_lu_16 (ReLU)              (None, 10, 10, 512)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 10, 10, 512)       262656
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 10, 10, 512)       2048
# _________________________________________________________________
# re_lu_17 (ReLU)              (None, 10, 10, 512)       0
# _________________________________________________________________
# depthwise_conv2d_9 (Depthwis (None, 10, 10, 512)       5120
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 10, 10, 512)       2048
# _________________________________________________________________
# re_lu_18 (ReLU)              (None, 10, 10, 512)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 10, 10, 512)       262656
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 10, 10, 512)       2048
# _________________________________________________________________
# re_lu_19 (ReLU)              (None, 10, 10, 512)       0
# _________________________________________________________________
# depthwise_conv2d_10 (Depthwi (None, 10, 10, 512)       5120
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 10, 10, 512)       2048
# _________________________________________________________________
# re_lu_20 (ReLU)              (None, 10, 10, 512)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 10, 10, 512)       262656
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 10, 10, 512)       2048
# _________________________________________________________________
# re_lu_21 (ReLU)              (None, 10, 10, 512)       0
# _________________________________________________________________
# depthwise_conv2d_11 (Depthwi (None, 10, 10, 512)       5120
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 10, 10, 512)       2048
# _________________________________________________________________
# re_lu_22 (ReLU)              (None, 10, 10, 512)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 10, 10, 512)       262656
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 10, 10, 512)       2048
# _________________________________________________________________
# re_lu_23 (ReLU)              (None, 10, 10, 512)       0
# _________________________________________________________________
# depthwise_conv2d_12 (Depthwi (None, 5, 5, 512)         5120
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 5, 5, 512)         2048
# _________________________________________________________________
# re_lu_24 (ReLU)              (None, 5, 5, 512)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 5, 5, 1024)        525312
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 5, 5, 1024)        4096
# _________________________________________________________________
# re_lu_25 (ReLU)              (None, 5, 5, 1024)        0
# _________________________________________________________________
# depthwise_conv2d_13 (Depthwi (None, 5, 5, 1024)        10240
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 5, 5, 1024)        4096
# _________________________________________________________________
# re_lu_26 (ReLU)              (None, 5, 5, 1024)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 5, 5, 1024)        1049600
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 5, 5, 1024)        4096
# _________________________________________________________________
# re_lu_27 (ReLU)              (None, 5, 5, 1024)        0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 3,243,908
# Trainable params: 3,222,020
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
SVG(model_to_dot(model).create(prog='dot', format='svg'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['acc'])

# %%
epochs=3 if FAST_RUN else 50
history = model.fit_generator(
    train_generator, 
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=total_validate//batch_size,
    steps_per_epoch=total_train//batch_size,
    callbacks=callbacks
)
# Out:
# WARNING:tensorflow:From /home/shiv/.local/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/50
# 213/213 [==============================] - 543s 3s/step - loss: 1.0974 - acc: 0.5441 - val_loss: 2.0071 - val_acc: 0.2503
# Epoch 2/50
# 213/213 [==============================] - 494s 2s/step - loss: 0.8035 - acc: 0.6662 - val_loss: 1.6993 - val_acc: 0.2510
# Epoch 3/50
# 213/213 [==============================] - 520s 2s/step - loss: 0.7592 - acc: 0.6914 - val_loss: 1.4827 - val_acc: 0.3452
# Epoch 4/50
# 213/213 [==============================] - 509s 2s/step - loss: 0.6587 - acc: 0.7429 - val_loss: 3.7777 - val_acc: 0.5962
# Epoch 5/50
# 213/213 [==============================] - 489s 2s/step - loss: 0.6261 - acc: 0.7601 - val_loss: 0.9463 - val_acc: 0.5019
# Epoch 6/50
# 213/213 [==============================] - 494s 2s/step - loss: 0.5852 - acc: 0.7584 - val_loss: 1.9870 - val_acc: 0.3401
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 7/50
# 213/213 [==============================] - 478s 2s/step - loss: 0.5338 - acc: 0.7937 - val_loss: 1.3885 - val_acc: 0.7236
# Epoch 8/50
# 213/213 [==============================] - 497s 2s/step - loss: 0.4785 - acc: 0.8022 - val_loss: 0.5163 - val_acc: 0.7541
# Epoch 9/50
# 213/213 [==============================] - 511s 2s/step - loss: 0.4593 - acc: 0.8135 - val_loss: 2.3592 - val_acc: 0.5172
# Epoch 10/50
# 213/213 [==============================] - 511s 2s/step - loss: 0.4632 - acc: 0.8144 - val_loss: 0.8070 - val_acc: 0.7185
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 11/50
# 213/213 [==============================] - 468s 2s/step - loss: 0.3926 - acc: 0.8449 - val_loss: 0.9465 - val_acc: 0.6803
# Epoch 12/50
# 213/213 [==============================] - 519s 2s/step - loss: 0.3796 - acc: 0.8499 - val_loss: 0.4064 - val_acc: 0.6790
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 13/50
# 213/213 [==============================] - 499s 2s/step - loss: 0.3294 - acc: 0.8697 - val_loss: 0.6813 - val_acc: 0.6548
# Epoch 14/50
# 213/213 [==============================] - 477s 2s/step - loss: 0.3286 - acc: 0.8694 - val_loss: 0.3892 - val_acc: 0.6242
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 15/50
# 213/213 [==============================] - 502s 2s/step - loss: 0.3200 - acc: 0.8717 - val_loss: 1.1226 - val_acc: 0.6701
# Epoch 16/50
# 213/213 [==============================] - 544s 3s/step - loss: 0.3291 - acc: 0.8743 - val_loss: 0.4920 - val_acc: 0.6879
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 17/50
# 213/213 [==============================] - 492s 2s/step - loss: 0.3111 - acc: 0.8788 - val_loss: 0.9737 - val_acc: 0.6433
# Epoch 18/50
# 213/213 [==============================] - 525s 2s/step - loss: 0.2981 - acc: 0.8889 - val_loss: 1.4173 - val_acc: 0.6739
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 19/50
# 213/213 [==============================] - 548s 3s/step - loss: 0.3112 - acc: 0.8800 - val_loss: 0.2997 - val_acc: 0.6688
# Epoch 20/50
# 213/213 [==============================] - 529s 2s/step - loss: 0.2958 - acc: 0.8826 - val_loss: 1.2758 - val_acc: 0.6943
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 21/50
# 213/213 [==============================] - 504s 2s/step - loss: 0.2751 - acc: 0.8882 - val_loss: 0.8422 - val_acc: 0.6841
# Epoch 22/50
# 213/213 [==============================] - 532s 2s/step - loss: 0.2774 - acc: 0.8911 - val_loss: 1.5207 - val_acc: 0.6879
# Epoch 23/50
# 213/213 [==============================] - 508s 2s/step - loss: 0.3023 - acc: 0.8907 - val_loss: 0.6008 - val_acc: 0.6650
# Epoch 24/50
# 213/213 [==============================] - 541s 3s/step - loss: 0.2973 - acc: 0.8863 - val_loss: 1.1158 - val_acc: 0.6892
# Epoch 25/50
# 213/213 [==============================] - 527s 2s/step - loss: 0.2715 - acc: 0.8932 - val_loss: 0.8162 - val_acc: 0.6471
# Epoch 26/50
# 213/213 [==============================] - 497s 2s/step - loss: 0.2718 - acc: 0.8885 - val_loss: 1.3545 - val_acc: 0.6828
# Epoch 27/50
# 213/213 [==============================] - 496s 2s/step - loss: 0.2876 - acc: 0.8883 - val_loss: 2.1598 - val_acc: 0.6561
# Epoch 28/50
# 213/213 [==============================] - 513s 2s/step - loss: 0.2624 - acc: 0.9020 - val_loss: 1.2905 - val_acc: 0.6828
# Epoch 29/50
# 213/213 [==============================] - 497s 2s/step - loss: 0.2866 - acc: 0.8889 - val_loss: 0.9026 - val_acc: 0.6892

# %%
loss, accuracy = model.evaluate_generator(validation_generator, total_validate//batch_size, workers=12)
print("Test: accuracy = %f  ;  loss = %f " % (accuracy, loss))
# Out:
# Test: accuracy = 0.685535  ;  loss = 0.606970

# %%
def plot_model_history(model_history, accuracy='acc', val_accuracy='val_acc'):
    fig, axs = plt.subplots(1,2,figsize=(20,20))
    axs[0].plot(range(1,len(model_history.history[accuracy])+1),model_history.history[accuracy])
    axs[0].plot(range(1,len(model_history.history[val_accuracy])+1),model_history.history[val_accuracy])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history[accuracy])+1),len(model_history.history[accuracy])/10)
    axs[0].legend(['train', 'val'], loc='best')
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()
    
plot_model_history(history)

# %%
df1['category'] =df1['category'].replace({ 'c1':0,'c2':1,'c3':2,'c4':3})

# %%
Y_val=df1['category']

# %%
Y_val =Y_val.replace({ 0:'0', 1:'1',2:'2',3:'3'})

# %%
from sklearn.preprocessing import MultiLabelBinarizer
one_hot = MultiLabelBinarizer()
Y_val = one_hot.fit_transform(Y_val)

# %%
Y_val = [ np.argmax(t) for t in Y_val ]

# %%
y_pred =  model.predict_generator(validation_generator)
y_pred
# Out:
# array([[1.84816748e-01, 1.70896035e-02, 7.96677589e-01, 1.41602242e-03],
#        [1.13591939e-01, 1.82727814e-01, 6.93726480e-01, 9.95376613e-03],
#        [8.90940547e-01, 1.09049007e-01, 8.58899784e-06, 1.85177726e-06],
#        ...,
#        [2.69673169e-01, 7.26350784e-01, 3.88464192e-03, 9.13737458e-05],
#        [8.80808949e-01, 1.18407145e-01, 7.65543606e-04, 1.83974789e-05],
#        [2.52862515e-06, 1.35122818e-07, 9.99933004e-01, 6.43181484e-05]],
#       dtype=float32)

# %%
threshold = 0.5
y_final = np.where(y_pred > threshold, 1,0)
y_final = [ np.argmax(t) for t in y_final ]

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
# Predict the values from the validation dataset

# compute the confusion matrix
confusion_mtx = confusion_matrix(Y_val, y_final)
# plot the confusion matrix
f,ax = plt.subplots(figsize=(8, 8))
sns.heatmap(confusion_mtx, annot=True, linewidths=0.01,cmap="Greens",linecolor="gray", fmt= '.1f',ax=ax)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import classification_report

# Generate a classification report
report = classification_report(Y_val, y_final, target_names=['0','1','2','3'])

print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.24      0.42      0.31       200
#            1       0.22      0.10      0.14       200
#            2       0.26      0.25      0.25       200
#            3       0.23      0.18      0.20       200
#
#     accuracy                           0.24       800
#    macro avg       0.24      0.24      0.22       800
# weighted avg       0.24      0.24      0.22       800

# %%
test_filenames = os.listdir("/home/shiv/Desktop/tob_train_extra")
test_df = pd.DataFrame({
    'filename': test_filenames
})
nb_samples = test_df.shape[0]

# %%
test_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_gen.flow_from_dataframe(
    test_df, 
    "/home/shiv/Desktop/tob_train_extra", 
    x_col='filename',
    y_col=None,
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 300 validated image filenames.

# %%
predict = model.predict_generator(test_generator, steps=np.ceil(nb_samples/batch_size))

# %%
test_df['category'] = np.argmax(predict, axis=-1)

# %%
label_map = dict((v,k) for k,v in train_generator.class_indices.items())
test_df['category'] = test_df['category'].replace(label_map)
test_df['category'] = test_df['category'].replace({ 'c1': 0, 'c2': 1,'c3': 2,'c4': 3})
test_df['category'].value_counts().plot.bar()

# %%
sample_test = test_df.head(18)
sample_test.head()
plt.figure(figsize=(12, 24))
for index, row in sample_test.iterrows():
    filename = row['filename']
    category = row['category']
    img = load_img("/home/shiv/Desktop/tob_train_extra/"+filename, target_size=IMAGE_SIZE)
    plt.subplot(6, 3, index+1)
    plt.imshow(img)
    plt.xlabel(filename + '(' + "{}".format(category) + ')' )
plt.tight_layout()
plt.show()
